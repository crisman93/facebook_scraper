# %%
from facebook_scraper import get_posts
import pandas as pd

# %% [markdown]
# # Scrape FB Page comments

# %%
def scrape_comments(fb_group_list, pages, cookies_file, options):
    """
    Made this dataframe based on: https://github.com/kevinzg/facebook-scraper
    
    Args:
        fb_group_list(str, list): a list of Facebook pages to scrape, must be public
        pages(int): number of pages to collect
        cookies_file(str): file location of cookies data
        options(dict): dictionary of options for collection, dictionary options can be found in the link above
        
    Returns:
        DataFrame: a DataFrame containing comments and associated information from posts scraped. Posts scraped are gathered from 'fb_group_list' posts that 
                   that contain words inputted in 'words_list'
    """
    # If content in the 'comment_text' column is the commenters name it is most likely because they commented with just a picture and no text
    post_list = []
    df_comments = pd.DataFrame()
    for fb_group in fb_group_list:
        for post in get_posts(fb_group, pages = pages, cookies = cookies_file, options = options):
            post['text'] = post['text'].split('\n',1)[0]
            comments_list = []
            replies_list = []
            
            print(post['text']+'\n')
            post_list.append(post)
            x = 0
                
            while x < len(post_list):
                comments_list = post_list[x]['comments_full']
                x+=1

                if comments_list != []:
                    i = 0
                    comment_text = comments_list[i]['comment_text']

                    for comment in comment_text:
                        while i < len(comments_list):
                            comments_list[i]['comment_text'] = comments_list[i]['comment_text'].split('\n',1)[0]
                            replies_list = comments_list[i]['replies']
                            i+=1

                            if replies_list != []:
                                z = 0

                                while z < len(replies_list):
                                    replies_list[z]['comment_text'] = replies_list[z]['comment_text'].split('\n',1)[0]
                                    z+=1
            df_comments = df_comments.append(comments_list)
    print('Done')
    return df_comments

# %%
# Initialize function parameters 
fb_page_list = ['']

# Still need to get these FB pages:, Fairbanks Borough, Kenai Peninsula Borough
cookies = ('facebook.com_cookies.txt')
words_list = ['']

# %%
comments = scrape_comments(fb_page_list, 10, cookies, {"comments": True, "reactors": True, "allow_extra_requests": True, 'posts_per_page': 1})
# Out:
# Congress is largely backing President Joe Biden’s decision to confront Russia with potentially escalating sanctions for the crisis in Ukraine as lawmakers brace for perhaps the most daunting foreign policy crisis the nation has faced in a generation.
#
# For Southcentral Alaska, rain and snow moves back in. Anchorage is on the edge of the action and the highest chance of seeing the rain and snow here is on Friday.
#
# Starting in fiscal year 2023, the Anchorage School District will pay for 75% of its School Resource Officer program, a shift of more than $2 million dollars from the municipality to the school district. The city had fully funded the program since 2015.
#
# Downtown Anchorage is getting a new makeover, as ongoing efforts to try and get more businesses to set up shop downtown continue.
#
# A shovel, fish clubs, a bracelet with a knife in it, and even a blowtorch. These are all items people tried to get through the Transportation Security Agency with at the Ted Stevens Anchorage International Airport.
#
# Anchorage’s recent warm temperatures are causing a bit of concern for one of Fur Rondezvous’ biggest events. The Fur Rondy Open World Championship Sled Dog Races start Friday and some parts of the trail could still use work.
#
# Target has updated its COVID-19 mask guidance to no longer require staff or guests to wear masks in stores.
#
# UPDATED: Russian President Vladimir Putin on Thursday announced a military operation in Ukraine, claiming it’s intended to protect civilians. In a televised address, Putin said the action comes in response to threats coming from Ukraine.
#
# The U.S. Postal Service said Wednesday it cleared the final regulatory hurdle to placing orders for next-generation mail vehicles — and getting some of them on delivery routes next year — despite pushback from the Environmental Protection Agency.
#
# The military along with federal and state agencies are taking part in the 10th iteration of the Arctic Eagle-Patriot exercise in Alaska, which teaches emergency response in the Arctic environment.
#
# Three states — including Alaska — that would be affected by a proposed 6-cent per gallon tax on fuel exported from Washington state are pushing back on the plan, and threatening to retaliate if it is signed into law.
#
# The Alaska Legislature has advanced a plan to convert a state-owned building into 33 apartments for legislators and staff at an estimated cost of $5.5 million.
#
# Lawyers for former Alaska Gov. Sarah Palin are seeking a new trial on her defamation claims against The New York Times, along with a Manhattan judge's removal from the case.
#
# Canadian Prime Minister Justin Trudeau announced Wednesday he is removing emergency powers police can use after authorities ended the blockades at the borders and the occupation in Ottawa by truckers and others opposed to COVID-19 restrictions.
#
# A jury that appears to be all-white began deliberating Wednesday at the federal trial of three fired Minneapolis police officers charged with violating George Floyd’s civil rights when he was pinned to the ground.
#
# FUR RONDY: The AT&T Fireworks Extravaganza is greatly anticipated as one of the highlights of the Fur Rondy Festival! Fireworks will once again be visible to revelers throughout much of downtown and beyond. The winter sky over Anchorage will never be brighter!
#
# Is your mom your biggest fan? Reporter Myles Harris’ mother, Sandi, is his. She stopped by to surprise him at work, but he was in the field reporting on camera.
#
# The leaders of the Senate Judiciary Committee are demanding Attorney General Merrick Garland take immediate action to reform the beleaguered federal Bureau of Prisons in response to Associated Press investigations that exposed widespread problems there.
#
# Alaska legislative leaders have voted to make mask wearing optional at legislative facilities, including the state Capitol, though mask use by lawmakers prior to the vote was in some cases spotty.
#
# Ukraine on Wednesday declared a nationwide state of emergency after Russian President Vladimir Putin received authorization to use military force outside his country and the West responded with sanctions.
#
# There are 23 adult intensive care unit beds available statewide, but just one in Anchorage.
#
# The two prosecutors in charge of the Manhattan district attorney’s criminal investigation into former President Donald Trump suddenly resigned Wednesday, throwing the future of the probe into question.
#
# The syndrome only affects certain people, and doctors aren’t quite sure who is at risk of developing symptoms.
#
# Chuck White owns Alaska high school basketball records for wins, state titles and conference championships. He passed away in 2019, and now, former players and those he impacted can visit him to honor his memory.
#
# After two years of silence, arenas in Anchorage are once again filled with the sound of dribbling from the All Alaska Native Fur Rondy Basketball Tournament.
# C:\Users\crist\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# CDC officials are pointing to research showing that a longer interval of time between Moderna or Pfizer's COVID-19 shots can provide more enduring protection against the coronavirus.
#
# A preliminary budget for fiscal year 2023 worth up to $850 million has been passed by the Anchorage School Board.
#
# State TV is reporting that Iran has returned 820,000 doses of coronavirus vaccines donated by Poland because they were manufactured in the United States.
#
# Starting next year, the extra money you’ve been making on third-party marketplace apps like Amazon, eBay, Etsy or Facebook Market, may just get taxed.
#
# The possibility that the vaccines could somehow prompt the condition is only theoretical and an analysis of U.S. government data found no evidence that it did.
#
# The convoys follow the recent Canadian truckers’ protest which shut down the busiest U.S. Canadian border crossing and besieged the streets of the capital for weeks.
#
#
# U.S. auto safety regulators have launched another investigation of Tesla, this time tied to complaints that its cars can stop on roads for no apparent reason.
#
# A U.S. Coast Guard vessel offloaded more than 30 metric tons of cocaine and marijuana worth over $1 billion that was seized at sea during a months-long deployment.
#
# The last line of the letter sent by the Indiana school reads, “If you would like to opt your child out of receiving these lessons, then sign the form below and have your child return it to the school to give to the teacher.”
#
# Since July, the Anchorage Office of Economic and Community Development has been tasked by the mayor with making the permitting process more modern and user-friendly in a manner that is fast, efficient and easy to do.
#
# An Anchorage Superior Court judge has sided with the state in a lawsuit brought by four college students who argued it was unconstitutional to drain the state’s scholarship fund.
#
# Legislation averting a weekend government shutdown easily cleared an initial hurdle Thursday as the Senate advanced a measure designed to give bipartisan bargainers more time to reach an overdue deal financing federal agencies until fall.
#
# The body of a missing boater was recovered by the U.S. Coast Guard near Ketchikan.
#
# OxyContin maker Purdue Pharma and a group of states have not been able to agree on a multibillion-dollar settlement of lawsuits over the drug’s role in the opioid crisis after more than a month of mediation.
#
# Gov. Mike Dunleavy is discussing his legislative priorities on the PFD and fighting crime, during an update on the progress of the session.
#
# According to court documents, five administrators at a Christian school were arrested and charged with failing to report an incident with the intent to conceal neglect or abuse.
#
# Anchorage Assembly member Chris Constant announced his candidacy for the U.S. House of Representatives on Thursday. Constant held a press conference at the 49th State Brewing Company building Thursday morning to announce his intent to run.
#
# A mother and father are dealing with the loss of all four of their young children.
#
# The researchers also found elevated levels of lead exposure in fall and winter, coinciding with hunting season in many states.
#
# Reported sexual assaults at the U.S. military academies increased sharply during the 2020-21 school year.
#
# A 13-month-old boy is back home with his family, recovering from COVID-19, after being placed on a heart-lung machine.
#
# Police are bracing for a crackdown in downtown Ottawa as Canadian Prime Minister Justin Trudeau called a nearly three-week trucker vaccine mandate protest a threat to the country's economy and public safety.
#
# President Joe Biden warned that Russia could still invade Ukraine within days, after Russia expelled the No. 2 diplomat at the U.S. Embassy in Moscow, as tensions flared anew in the worst East-West standoff in decades.
#
# Millions of Americans’ immune systems now recognize the virus and are primed to fight it off if they encounter omicron.
#
# Kamila Valieva, who is at the center of the latest Russian doping controversy, missed the podium with a mistake-filled end to her Olympic dream.
#
# It's still warm and sloppy around Southcentral Alaska today as rain falls across Anchorage. This will continue to lead to ponding on the roads and continued snowmelt across the region.
#
# New York Attorney General Letitia James wants her investigators to be able to question Donald Trump and his children after evidence surfaced revealing more insight into the Trump company's questionable business practices.
#
# The Alaska State Hospitals and Nursing Home Association recently did an Alaska Healthcare Workforce Analysis, and found there were 6,300 job openings industry-wide in Alaska. Registered nurses led the way with 1,400 openings.
#
# All but one school in the Matanuska-Susitna Borough School District will be closed today as students resort to online learning.
#
# The Canadians finished 7-0 and spent their time in Beijing showcasing a dynamic, deep and relentless offensive attack to capture their fifth Olympic title in seven tournaments, with four coming against the Americans.
#
# Alaska celebrated Elizabeth Peratrovich Day on Feb. 16, remembering the work of the Alaska Native civil rights leader who was instrumental in bringing about the passage of Alaska's Anti-Discrimination Act of 1945.
#
# The leader of the Federal Aviation Administration, whose agency has been criticized for its oversight of Boeing and handling of questions surrounding 5G interference with aircraft, said he will step down March 31.
#
# An Anchorage family released balloons on the anniversary of Brandy Sullivan's death in 2017. The trial for her then-husband, who faces murder charges in her death, is ongoing.
#
# After Anchorage got hit with a warm weather pattern Tuesday that caused slick driving conditions all around the city, that warm weather moved into the Matanuska-Susitna Valley early Wednesday morning.
#
# The Anchorage Assembly postponed taking action on a proposal from Mayor Dave Bronson's administration that would create a property tax exemption for people who construct accessory dwelling units on their property.
#
# Freestyler skier Alex Hall, who was born in Fairbanks, took gold in the men’s Olympic slopestyle competition.
#
# The Anchorage Community Development Authority is still in search of a new leaseholder for the Nordstrom building on D Street, which has sat dormant for the last two and a half years.
#
# Ukrainians defied pressure from Moscow with a national show of flag-waving unity Wednesday, while the U.S. warned that Russia had added as many as 7,000 troops near Ukraine’s borders despite Kremlin declarations that forces were being pulled back.
#
# The continued snow has caused problems for not only drivers, but pedestrians trying to walk the sidewalks.
#
# Boodle is the U.S. Military Academy’s slang for snacks, food, or candy. The Alaska All Academies Association sends the boxes to Alaskans at the U.S. Naval Academy, the Air Force Academy, the U.S. Coast Guard Academy, and the U.S. Merchant Marine Academy.
#
# The judge presiding over Sarah Palin’s libel lawsuit against The New York Times says jurors knew before delivering their verdict that he’d already decided to rule against Palin.
#
# A Fairbanks man has been found guilty of murder for the strangulation killing of his girlfriend and mother of two children, Robyn Gray, back in 2017.
#
# An Anchorage Superior Court judge has struck down a new Senate map as unconstitutional that pairs parts of East Anchorage with Eagle River and a House district that connects Skagway with the Mendenall Valley in Juneau.
#
# America’s coastline will see sea levels rise in the next 30 years by as much as they did in the entire 20th century, with major Eastern cities hit regularly with costly floods even on sunny days, a government report warns.
#
# Drug overdoses in the U.S. are skyrocketing, as evidenced by a recent 12-month period showing double the amount from six years ago. Experts say the COVID-19 pandemic is partially to blame.
#
# President Joe Biden is ordering the release of Trump White House visitor logs to the House committee investigating the riot of Jan. 6, 2021.
#
# The state of Alaska reported 863 new COVID-19 cases on Wednesday and lost the dubious title as the state in the U.S. with the highest rate of new cases, now ranking second to Maine for the first time in three weeks.
#
# As the demand for COVID testing skyrocketed during the omicron variant peak, it left consumers scrambling with long lines at testing sites and a limited supply of at-home testing kits.
#
# More than 50 million households have received their free at-home COVID-19 tests from the federal government.
#
# Melissa Frey
#
# Former U.S. Interior Secretary Ryan Zinke misused his position to advance a commercial development project that included a microbrewery in his Montana hometown and lied to an agency ethics official about his involvement, federal investigators reported.
#
# The suit says the family would suffer extreme mental pain, anguish and emotional distress if the information were released.
#
# AT&T customers should check their devices now to potentially avoid losing service.
#
# This nonstop snowy pattern continues to lead to significant impacts across the region.
#
# Winter storms have created havoc for plow crews in Anchorage.
#
# Authorities in yellow “police liaison” vests went from rig to rig, knocking on the doors of the trucks parked outside Parliament, to serve notice to the truckers that they could also lose their licenses and see their vehicles seized.
#
# The Sullivan Arena has been operating as a mass care homeless shelter since the start of the COVID-19 pandemic. The Anchorage Health Department said it has been making modifications to improve safety for the hundreds of people staying at the shelter.
#
# All Anchorage schools are closed, Mat-Su schools are moving to remote learning and most Kenai Peninsula schools are closed Wednesday with the exception of a few on delayed starts as wintry weather makes a mess of Southcentral.
#
# UPDATED: Alaska Department of Transportation and Public Facilities crews will be working double shifts on Tuesday night. Plow crews will begin with high priority roads, such as Minnesota Drive and the Seward and Glenn Highways.
#
# The Anchorage Assembly is considering a new ordinance aimed at capping the amount of time a person can serve as acting mayor when there is a vacancy. A previous measure would have done this by changing city charter; this one would change city code instead.
#
# Work is underway to improve the North Terminal at Ted Stevens Anchorage International Airport. That section of the airport opened back in the early 1980s.
#
# Southcentral Alaska should be prepared for dangerous driving conditions as another round of heavy snow and rain moves in overnight and continues Wednesday. Chief Meteorologist Melissa Frey's forecast is below.
#
# As mid-February approaches, data from the Alaska Department of Health and Social Services shows the state’s COVID-19 cases are trending down after January’s case count hit record high numbers with more than 62,000 cases reported throughout the month.
#
# Attorneys have flagged several potential issues with Gov. Mike Dunleavy’s executive order that would split the state’s health department in two, including that it contains “a number of drafting errors” and could be substantively amending state statutes.
#
# One Anchorage souvenir shop is facing a civil lawsuit by the state of Alaska for allegedly selling fake “Made in Alaska” products.
#
# A provision in a U.S. Senate bill would expand tribal court jurisdiction for up to 30 Alaska tribes as part of a pilot program aimed at addressing high rates of violence.
#
# The Biden administration is telling Congress that it needs an additional $30 billion to press ahead with the fight against COVID-19.
#
# Alaska experiences a number of different disasters such as earthquakes and volcano eruptions, but events like wildfires, floods and erosion can be heavily driven by high winds.
#
# Farms that raise turkeys and chickens for meat and eggs are on high alert and taking steps to increase biosecurity, fearing a repeat of a widespread bird flu outbreak in 2015 that killed 50 million birds and cost the federal government nearly $1 billion.
#
# Anyone who has ever been temporarily blinded by high-beam headlights from an oncoming car will be happy to hear this.
#
# A new temporary drive-thru COVID-19 testing site is opening in Midtown Anchorage that will be open six days a week.
#
# UPDATED: A man facing charges in a stabbing incident Sunday at the Loussac Library had been found incompetent to stand trial in January in a felony assault case and released. He had also encountered police in a separate incident on Feb. 10.
#
# Back to back storms are bringing snow and freezing rain to Southcentral. A second round is expected Tuesday night/Wednesday morning. Chief Meteorologist Melissa Frey explains what's happening and just how much more snow we might receive.
#
# Multiple accidents have plagued the streets of Anchorage due to icy conditions, including a People Mover bus that stopped traffic in one Midtown location.
#
# The man picked by President Joe Biden to lead the Food and Drug Administration narrowly made it through the Senate, despite political polarization surrounding the choice.
#
# All after-school activities Tuesday in the Anchorage School District have been canceled due to icy road conditions.
#
# As far-right movements fueled by conspiracy theories, misogyny and anti-vaccine proponents continue to grow and evolve into different groups, the number of associated killings are also climbing, according to a new report.
#
# A man was taken into custody after allegedly stabbing a woman at Loussac Library.
#
# The police chief of Ottawa, Canada, has resigned amid criticism of his inaction against the trucker protests that have paralyzed Canada’s capital for over two weeks.
#
# Former Gov. Sarah Palin lost her libel lawsuit against the New York Times when the jury rejected her case on an erroneous claim by the newspaper linking her campaign rhetoric to a mass shooting.
#
#
# While travel in general is getting more expensive, used car prices are really skyrocketing.
#
# Alaska saw over 1,800 new COVID-19 cases over the weekend, reflecting a continued trend of declining case numbers. Overall, over the past seven days, the state has seen a 45% drop in new cases, compared to the previous 7-day period.
#
# A use-of-force expert testified that the conduct used by three Minneapolis police officers was "inconsistent" with generally accepted policing practices.
#
# The 2020 cruise ship season was wiped out, and the 2021 season was severely stunted, but Alaskan cruise companies are predicting a major return of the industry in 2022.
#
# The 30-second TV ad that flashed across the screen during the Super Bowl? It got so many hits in one minute, it crashed the company's website, and skyrocketed from 186th place to second on Apple's app store.
#
# A judge says he will dismiss a libel lawsuit that former Alaska Gov. Sarah Palin filed against The New York Times.
#
# A Russian attack may not be as imminent as some believe, as the Kremlin signaled that they may be ready to keep talking with western countries about security grievances.
#
# The Girdwood Fire Department recently had a life-saving piece of rescue equipment break due to old age, and the fire chief is saying enough is enough.
#
# After receiving criticism for comments Jan. 31 on the daytime talk show where she said the Holocaust was not about race, but rather about man’s inhumanity to others, Whoopi Goldberg is returning.
#
# Authorities have released Brian Laundrie’s autopsy results to the public following the discovery of his skeletal remains at the Myakkahatchee Creek Environmental Park in Florida.
#
# Three new bills focus on sex trafficking as a growing problem in Alaska, but when Alaska’s News Source looked into the number of arrests made by local and state law enforcement for the crime over the last few years, there were very few.
#
# Ontario will be lifting its COVID-19 proof-of-vaccination requirements in two weeks — not because of the protests that have blocked the border and paralyzed Ottawa, but because the premier said “it is safe to do so.”
#
# Four years after 17 people were gunned down at Stoneman Douglas High School in Parkland, Florida, families and gun control advocates are pressing President Joe Biden to do more to address gun violence.
#
# Sunday was a big night for Los Angeles Rams wide receiver Van Jefferson, who is now both a Super Bowl champion and a new dad.
#
# ...
#
# A recent survey found that over 600 small businesses statewide were feeling more optimistic for the year ahead, even as issues related to the pandemic remain a hurdle with 45% of businesses surveyed saying it remains the next most major challenge.
#
# SpaceX’s Elon Musk said that the first orbital flight of his towering Starship — the world’s most powerful rocket ever built — could come in another month or two.
#
# With the government reporting Thursday that consumer inflation reached 7.5% over the past year — a 40-year high — the acceleration of prices is leaving few unscathed.
#
# It’s an uncommon outcome for any pregnancy, but women with COVID-19 face an elevated risk. Authorities believe vaccination can help prevent these cases.
#
# The CIA has an undisclosed data repository that includes information collected about Americans, two Democrats on the Senate Intelligence Committee said. The senators alleged the CIA had long hidden details about the program from the public and Congress.
#
# The first round of snow for Anchorage starts overnight tonight, with coastal areas of Southcentral Alaska seeing the most snowfall. Through the day Friday, there will be another break for the city before snow resumes Friday night to Saturday.
#
# A team of 50 scientists from the Lower 48 and Europe have converged on Fairbanks for a seven-week winter research project. The project, however, does not focus on snow or ice, but rather on poor air quality the city experiences quite often in the winter.
#
# Girdwood Fire and Rescue is looking to fill eight spots on their team, but they’re specifically looking for people that live in Girdwood, and that’s because 70% of their team commutes from Anchorage.
#
# The Alaska Department of Transportation and Public Facilities and the Municipality of Anchorage are discussing the potential transfer of the Birchwood Airport ownership to the city
#
# Former Alaska Sen. Johnny Ellis, who represented Anchorage in the Alaska Legislature for nearly 30 years before his retirement, died on Thursday at the age of 61.
#
# The Anchorage School Board voted last year to rename Fairview Elementary to Dr. Etheldra Davis Fairview Elementary School in honor of the first Black teacher hired by the Anchorage School District.
#
# It has left some Texas patients traveling hundreds of miles to clinics in neighboring states or farther, causing a backlog of appointments in those places.
#
# States are getting the go-ahead to build a nationwide network of electric vehicle charging stations that would place new or upgraded ones every 50 miles along interstate highways. Over five years, $5 billion in federal money will be available.
#
# Rep. Chris Tuck, D-Anchorage, chairs the Military and Veterans’ Affairs Committee, and stressed that the hearing was strictly informational into the Oath Keepers, and not an investigation or inquisition into Rep. David Eastman.
#
# The painting shows three torsos and heads with hair but no facial features. The vandal drew eyes on two of them.
#
# The lack of information about Trump’s calls presents a new challenge to investigators as they work to create the most comprehensive record yet of the riot, with a particular focus on what the former president was doing in the White House during the attack.
#
# A federal appeals court has declined, for now, to allow the Biden administration to require COVID-19 vaccinations for federal employees.
#
# The bumper-to-bumper demonstration by the self-proclaimed Freedom Convoy entered its fourth day Thursday at the Ambassador Bridge connecting Windsor, Ontario, to Detroit, disrupting the flow of auto parts and other products between the two countries.
#
# The Senate passed one of the largest workplace reforms in decades on Thursday, forbidding employers from forcing workers with sexual misconduct claims into arbitration. Instead, the measure permits them to file lawsuits.
#
# The largest public power company in the U.S. is launching a program to develop and fund new small modular nuclear reactors as part of its strategy to dramatically reduce greenhouse gas emissions.
#
# The Centers for Disease Control and Prevention has released new guidelines for the cruise industry. In the CDC’s updated program, cruise ships can operate under one of three tiers.
#
# A judge has ordered federal protections to be restored for gray wolves across much of the U.S. after they were removed in the waning days of the Trump administration.
#
# FUR RONDY: This year’s new twist to the Miners and Trappers is sure to have you kickin’ it country with Nashville sounds. Presenting COUNTRY JAM, hosting national talents Granger Smith and Earl Dibbles Jr. with special Guest Kendall Marvel. The Miners and Trappers event is Friday, February 25, starting at 7:00 p.m.
#
# There are several expanded tax benefits available to Americans, even if they have little or no income from a job.
#
# Democratic lawmaker Elvi Gray-Jackson has announced her bid for the U.S. Senate, joining Alaska GOP challenger Kelly Tshibaka in attempts to unseat Republican incumbent Lisa Murkowski.
#
# Unable to tame inflation that has worsened sharply under his watch, President Joe Biden emphasized Thursday how his administration’s policies can cut prescription drug prices.
#
# Steven Downs, 47, was found guilty on the charges of murder and sexual assault in the April 1993 death of 20-year-old Sophie Sergie at the University of Alaska Fairbanks in Fairbanks Superior Court on Thursday.
#
# Steven Downs Verdict coming down in Fairbanks Court room. We previously received permission from the court to broadcast portions of this trial
#
# Two years into the COVID-19 pandemic, many of the nation's most vulnerable residents are still in jeopardy of catching the virus as many states are already letting up on pandemic restrictions meant to keep them safer.
#
# One man gave himself 52 weeks to break 52 world records in 2021, but Guinness World Records is still in the process of confirming all of them.
#
# Sarah Palin has compared The New York Times to “Goliath” and herself to “David” in their dispute over a 2017 editorial.
#
# The Labor Department said Thursday that consumer prices jumped 7.5% last month compared with a year earlier, the steepest year-over-year increase since February 1982.
#
# The Washington Post reported that the National Archives and Records Administration has asked the Justice Department to investigate whether former President Donald Trump violated federal law in the handling of documents.
#
# Over the course of the pandemic the FTC, along with the Food and Drug Administration, has sent out cease and desist letters to more than 400 companies and individuals urging them to remove unproven claims that their product treats or prevents COVID-19.
#
# Facing growing pressure to ease up on pandemic restrictions, the White House insisted Wednesday it is making plans for a less-disruptive phase of the national virus response.
#
# Nathan Chen completed his four-year journey toward an elusive Olympic gold medal Thursday, following his record short program at the Beijing Games with a near-perfect free skate that earned him a standing ovation from supporters.
#
# UPDATED: Despite PETA releasing a statement celebrating the withdrawal of Millennium Hotels and Resorts as an Iditarod sponsor after this year, the hotel's general manager said the organization was not a factor in the decision to stop sponsoring the race.
#
# Anchorage’s Reapportionment Committee is starting to narrow down the options for a new voting district map that will lead to a 12th Anchorage Assembly seat, and each district having two representatives.
#
# The Biden administration says a government grant program to help prevent additional harm to people who use illicit drugs will not pay for safer pipes to smoke crack or meth.
#
# The Alaska House of Representatives has introduced a resolution, known as a sense of the House, that would condemn comparisons between COVID-19 mandates and the Holocaust, as well as the Jan. 6 attack on the U.S. Capitol.
#
# Truck blockades of Canada’s capital and U.S. border crossings, including the vital bridge to Detroit, forced the shutdown of a Ford plant as the company warned the protests could have widespread implications for the North American auto industry.
#
# "While this doesn’t solve those challenges, it says, ‘we see you, we remember you,'" said St. John Pastor Emily Carroll. "And hopefully, it’s also a reminder for us that there’s work to do in our city on how we care for the vulnerable.”
#
# Bob Saget’s death last month stemmed from an accidental blow to the head, his family said in a statement.
#
# The Alaska Police and Fire Chaplains are looking for donations for a new vehicle after a shocking fire. Chaplain Fred Voss was on his way to Alaska Regional Hospital in the fall of 2020 when he felt his seat getting warm and smoke began to appear.
#
# Up to 40 of the 49 small SpaceX satellites launched last week have either reentered the atmosphere and burned up, or are on the verge of doing so, the company said in an online update Tuesday night.
#
# Pfizer is working to get its COVID-19 fighting pill used in more people. Paxlovid is currently authorized to treat COVID-19 in high-risk individuals 12 and older. Pfizer is planning to study the drug in children age 6 to 18.
#
# January turned out to be very busy for the Alaska National Guard as troops were deployed around the state to deal with several winter storms.
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pyquery\pyquery.py in fromstring(context, parser, custom_parser)
#      56             try:
# ---> 57                 result = getattr(etree, meth)(context)
#      58             except etree.XMLSyntaxError:
#
# src/lxml/etree.pyx in lxml.etree.fromstring()
#
# src/lxml/parser.pxi in lxml.etree._parseMemoryDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDoc()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDoc()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# XMLSyntaxError: xmlParseEntityRef: no name, line 1, column 1330 (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15524/4143291791.py in <module>
# ----> 1 comments = scrape_comments(fb_page_list, 10000000, cookies, {"comments": True, "reactors": True, "allow_extra_requests": True, 'posts_per_page': 1})
#
# ~\AppData\Local\Temp/ipykernel_15524/129500047.py in scrape_comments(fb_group_list, pages, cookies_file, options)
#      17     df_comments = pd.DataFrame()
#      18     for fb_group in fb_group_list:
# ---> 19         for post in get_posts(fb_group, pages = pages, cookies = cookies_file, options = options):
#      20             post['text'] = post['text'].split('\n',1)[0]
#      21             comments_list = []
#
# ~\anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py in _generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, **kwargs)
#     702             logger.debug("Extracting posts from page %s", i)
#     703             for post_element in page:
# --> 704                 post = extract_post_fn(post_element, options=options, request_fn=self.get)
#     705                 if remove_source:
#     706                     post.pop('source', None)
#
# ~\anaconda3\lib\site-packages\facebook_scraper\extractors.py in extract_post(raw_post, options, request_fn, full_post_html)
#      31     raw_post: RawPost, options: Options, request_fn: RequestFunction, full_post_html=None
#      32 ) -> Post:
# ---> 33     return PostExtractor(raw_post, options, request_fn, full_post_html).extract_post()
#      34
#      35
#
# ~\anaconda3\lib\site-packages\facebook_scraper\extractors.py in extract_post(self)
#     219                     post["comments_full"] = utils.safe_consume(post["comments_full"])
#     220                     for comment in post["comments_full"]:
# --> 221                         comment["replies"] = utils.safe_consume(comment["replies"])
#     222                         for reply in comment["replies"]:
#     223                             utils.safe_consume(reply["comment_reactors"])
#
# ~\anaconda3\lib\site-packages\facebook_scraper\utils.py in safe_consume(generator, sleep)
#     257     result = []
#     258     try:
# --> 259         for item in generator:
#     260             result.append(item)
#     261             time.sleep(sleep)
#
# ~\anaconda3\lib\site-packages\facebook_scraper\extractors.py in extract_comment_replies(self, replies_url)
#    1010             logger.debug(f"Fetching {replies_url}")
#    1011         try:
# -> 1012             response = self.request(replies_url)
#    1013         except exceptions.TemporarilyBanned:
#    1014             raise
#
# ~\anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py in get(self, url, **kwargs)
#     566                 url = utils.urljoin(FB_MOBILE_BASE_URL, url)
#     567             response = self.session.get(url=url, **self.requests_kwargs, **kwargs)
# --> 568             response.html.html = response.html.html.replace('<!--', '').replace('-->', '')
#     569             response.raise_for_status()
#     570             self.check_locale(response)
#
# ~\anaconda3\lib\site-packages\requests_html.py in html(self)
#     652     def html(self) -> HTML:
#     653         if not self._html:
# --> 654             self._html = HTML(session=self.session, url=self.url, html=self.content, default_encoding=self.encoding)
#     655
#     656         return self._html
#
# ~\anaconda3\lib\site-packages\requests_html.py in __init__(self, session, url, html, default_encoding, async_)
#     419         super(HTML, self).__init__(
#     420             # Convert unicode HTML to bytes.
# --> 421             element=PyQuery(html)('html') or PyQuery(f'<html>{html}</html>')('html'),
#     422             html=html,
#     423             url=url,
#
# ~\anaconda3\lib\site-packages\pyquery\pyquery.py in __init__(self, *args, **kwargs)
#     215             if isinstance(context, basestring):
#     216                 try:
# --> 217                     elements = fromstring(context, self.parser)
#     218                 except Exception:
#     219                     raise
#
# ~\anaconda3\lib\site-packages\pyquery\pyquery.py in fromstring(context, parser, custom_parser)
#      59                 if hasattr(context, 'seek'):
#      60                     context.seek(0)
# ---> 61                 result = getattr(lxml.html, meth)(context)
#      62             if isinstance(result, etree._ElementTree):
#      63                 return [result.getroot()]
#
# ~\anaconda3\lib\site-packages\lxml\html\__init__.py in fromstring(html, base_url, parser, **kw)
#     873     else:
#     874         is_full_html = _looks_like_full_html_unicode(html)
# --> 875     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#     876     if is_full_html:
#     877         return doc
#
# ~\anaconda3\lib\site-packages\lxml\html\__init__.py in document_fromstring(html, parser, ensure_head_body, **kw)
#     759     if parser is None:
#     760         parser = html_parser
# --> 761     value = etree.fromstring(html, parser, **kw)
#     762     if value is None:
#     763         raise etree.ParserError(
#
# src/lxml/etree.pyx in lxml.etree.fromstring()
#
# src/lxml/etree.pyx in lxml.etree._Document.getroot()
#
# src/lxml/etree.pyx in lxml.etree._elementFactory()
#
# src/lxml/classlookup.pxi in lxml.etree._parser_class_lookup()
#
# src/lxml/classlookup.pxi in lxml.etree._custom_class_lookup()
#
# ~\anaconda3\lib\site-packages\lxml\html\__init__.py in lookup(self, node_type, document, namespace, name)
#     733         self._element_classes = classes
#     734
# --> 735     def lookup(self, node_type, document, namespace, name):
#     736         if node_type == 'element':
#     737             return self._element_classes.get(name.lower(), HtmlElement)
#
# KeyboardInterrupt:

# %%
comments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35480/4207359708.py in <module>
# ----> 1 comments
#
# NameError: name 'comments' is not defined

# %%
comments.to_csv('comments.csv')

# %%
comments_filtered = comments[comments['comment_text'].str.contains('|'.join(words_list))]

# %%
comments_filtered.to_csv('comments.csv')

# %% [markdown]
# # Scrape FB Page Posts

# %%
# Only collects posts
def scrape_posts(fb_group_list, pages, cookies_file, options):
    post_list = []
    df_posts = pd.DataFrame()
    for fb_group in fb_group_list:
        for post in get_posts(fb_group, pages = pages, cookies = cookies_file, options = options):
            post['text'] = post['text'].split('\n',1)[0]
            post_list.append(post)
        df_posts = df_posts.append(post_list)
    return df_posts

# %%
# Initialize function parameters 
fb_group_list = ['']
cookies = ('facebook.com_cookies.txt')

# %%
posts = scrape_posts(fb_group_list, 100000000, cookies, {"comments": True, "allow_extra_requests": True})

# %%
posts.to_csv('')

# %% [markdown]
# # Scrape FB group comments

# %%
def scrape_comments(fb_group_list, pages, cookies_file, options):
    """
    Made this dataframe based on: https://github.com/kevinzg/facebook-scraper
    
    Args:
        fb_group_list(str, list): a list of Facebook pages to scrape, must be public
        pages(int): number of pages to collect
        cookies_file(str): file location of cookies data
        options(dict): dictionary of options for collection, dictionary options can be found in the link above
        
    Returns:
        DataFrame: a DataFrame containing comments and associated information from posts scraped. Posts scraped are gathered from 'fb_group_list' posts that 
                   that contain words inputted in 'words_list'
    """
    # If content in the 'comment_text' column is the commenters name it is most likely because they commented with just a picture and no text
    post_list = []
    df_comments = pd.DataFrame()
    for fb_group in fb_group_list:
        for post in get_posts(group = fb_group, pages = pages, cookies = cookies_file, options = options):
            post['text'] = post['text'].split('\n',1)[0]
            comments_list = []
            replies_list = []
            
            print(post['text']+'\n')
            post_list.append(post)
            x = 0
                
            while x < len(post_list):
                comments_list = post_list[x]['comments_full']
                x+=1

                if comments_list != []:
                    i = 0
                    comment_text = comments_list[i]['comment_text']

                    for comment in comment_text:
                        while i < len(comments_list):
                            comments_list[i]['comment_text'] = comments_list[i]['comment_text'].split('\n',1)[0]
                            replies_list = comments_list[i]['replies']
                            i+=1

                            if replies_list != []:
                                z = 0

                                while z < len(replies_list):
                                    replies_list[z]['comment_text'] = replies_list[z]['comment_text'].split('\n',1)[0]
                                    z+=1
            df_comments = df_comments.append(comments_list)
    print('Done')
    return df_comments

# %%
fb_group_list = ['northeastconvoy']

# %%
comments = scrape_comments(fb_group_list, 10000000, cookies, {"comments": True, "reactors": True, "allow_extra_requests": True, 'posts_per_page': 1})

# %% [markdown]
# # Scrape FB group posts

# %%
# Only collects posts
def scrape_group_posts(fb_group_list, pages, cookies_file, options):
    post_list = []
    df_posts = pd.DataFrame()
    for fb_group in fb_group_list:
        for post in get_posts(group = fb_group, pages = pages, cookies = cookies_file, options = options):
            if post['text'] is not None:
                post['text'] = post['text'].split('\n',1)[0]
                print(post['text']+'\n')
                post_list.append(post)
            df_posts = df_posts.append(post_list)
    return df_posts

# %%
# Initialize function parameters 
fb_group_list = ['2711696262309046']
cookies = ('facebook.com_cookies.txt')

# %%
group_posts = scrape_group_posts(fb_group_list, 10000000, cookies, {"comments": False, "allow_extra_requests": True, 'posts_per_page': 1})
# Out:
# Staging is OPEN at Adelanto Stadium. Join us!
#
# *** Attention ***
#
# **** Reminder - staging begins at 12:00 noon pst tomorrow, 2/22/2022, at Adelanto Stadium, 12000 Stadium Way.
#
# Here is the northeast routes (main route and feeder routes to the main) and gathering points. Routes are subject to change. More details on exact locations, dates and times will be out soon!
#
# Kris Young‎The People’s Convoy - Official
#
# **** Update - the southeast route is being revised. We apologize for any confusion this may have caused. I’m leaving the post up and turning off comments because of the connections made in the comments. A revised map will be posted ***
#
# Route is posted on the website for CA to DC for the main convoy. Specific locations and times are not listed for security purposes. Routes are subject to change
#
# Ted Nugent supports The People’s Convoy
#
# **** CALLING ALL TRUCK DRIVERS ****
#
# **** ATTENTION - IMPORTANT INFORMATION!! ****
#
# Tomorrow we will have starting location address, departure time, and route information to release. Please understand that we are fully aware of the risks to this convoy and it’s participants. We are doing everything possible to protect the trucks, truckers, and all people joining in. At no time will we be releasing the full route but we will be making you completely aware, in route, where we will be and when so that you can be a part of this amazing event.
#
# If you are in the north east of this great nation, please be sure to join our group for planning and routes in your area (when they are released)
#
# If you are in the south east, join our newly formed group for information! Pitch in and help the group organize to meet up with the main convoy coming from California! Make sure to read the announcements at the top of the group!
#
# Bikers4America has joined us! New link!
#
# Bikers4America has joined in!!
#
# **** ATTENTION ****
#
# On air now….
#
# 2/15/22 - Newsmax interview
#
# Eric Bolling - Newsmax interview up coming! Tune in!
#
# Today's Update
#
# Update on "The People's Convoy"
#
# Our website is LIVE!

# %%
posts.to_csv('')
